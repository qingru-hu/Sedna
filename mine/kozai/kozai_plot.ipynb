# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
planet_e = np.loadtxt("planet_e.txt")
x = range(len(planet_e))
plt.plot(x, planet_e)

# %%
mutual_inc = np.loadtxt("mutual_inc.txt")
x = range(len(mutual_inc))
plt.plot(x, mutual_inc)
